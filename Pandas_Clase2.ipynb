# %% [markdown]
# <a href="https://colab.research.google.com/github/Duvs11/pandas_1/blob/main/Pandas_Clase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataFrame - encuesta

# %%
import pandas as pd
import numpy as np

# %%
encuesta=pd.DataFrame(
    {
       "Julia": ["Me gustó","Fué horrible"],
       "Pedro": ["Fue delicioso","No estuvo mal"]
    },
    index=["Restaurante_1","Restaurante_2"]
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante_1      Me gustó  Fue delicioso
# Restaurante_2  Fué horrible  No estuvo mal

# %%
file="/content/Datos.csv"
miCsv=pd.read_csv(file)
miCsv.shape
miCsv.head()
# Out:
#    Estudiante_1   Estudiante_2   Estudiante_3
# 0            34             23             45
# 1            45             10             46
# 2            25             30             46

# %%
miPoke=pd.read_csv("/content/pokemonDB_dataset.csv")
miPoke.shape
miPoke.head()
# Out:
#           Pokemon        Type             Species         Height  \
# 0       Abomasnow  Grass, Ice  Frost Tree Pokémon  2.2 m (7′03″)
# 1  Mega Abomasnow  Grass, Ice  Frost Tree Pokémon  2.7 m (8′10″)
# 2            Abra     Psychic         Psi Pokémon  0.9 m (2′11″)
# 3           Absol        Dark    Disaster Pokémon  1.2 m (3′11″)
# 4      Mega Absol        Dark    Disaster Pokémon  1.2 m (3′11″)
#
#                  Weight                                          Abilities  \
# 0  135.5 kg (298.7 lbs)       1. Snow Warning, Soundproof (hidden ability)
# 1  185.0 kg (407.9 lbs)                                    1. Snow Warning
# 2    19.5 kg (43.0 lbs)  1. Synchronize, 2. Inner Focus, Magic Guard (h...
# 3   47.0 kg (103.6 lbs)  1. Pressure, 2. Super Luck, Justified (hidden ...
# 4   49.0 kg (108.0 lbs)                                    1. Magic Bounce
#
#               EV Yield                          Catch Rate  \
# 0  1 Attack, 1 Sp. Atk    60 (7.8% with PokéBall, full HP)
# ...

# %% [markdown]
# la función .describe() hace un recorrido de los datos estadísticos de las diferentes series del archivo

# %%
miPoke.describe()
# Out:
#            HP Base       HP Min       HP Max  Attack Base   Attack Min  \
# count  1215.000000  1215.000000  1215.000000  1215.000000  1215.000000
# mean     71.244444   252.397531   346.320165    81.152263   150.073251
# std      26.927819    54.187278    54.611949    32.037134    57.676629
# min       1.000000     1.000000     1.000000     5.000000    13.000000
# 25%      52.000000   214.000000   308.000000    57.000000   107.000000
# 50%      70.000000   250.000000   344.000000    80.000000   148.000000
# 75%      85.000000   280.000000   374.000000   100.000000   184.000000
# max     255.000000   620.000000   714.000000   190.000000   346.000000
#
#         Attack Max  Defense Base  Defense Min  Defense Max  \
# count  1215.000000   1215.000000  1215.000000  1215.000000
# mean    286.658436     75.007407   139.011523   273.128395
# std      70.480682     30.740999    55.341860    67.633071
# min     119.000000      5.000000    13.000000   119.000000
# ...

# %%
miPoke.rename(columns={"Type":"Tipo", "Species":"Especie", "Height":"Altura", "Weight":"Peso"}, inplace=True)
miPoke.head()
# Out:
#           Pokemon        Tipo             Especie         Altura  \
# 0       Abomasnow  Grass, Ice  Frost Tree Pokémon  2.2 m (7′03″)
# 1  Mega Abomasnow  Grass, Ice  Frost Tree Pokémon  2.7 m (8′10″)
# 2            Abra     Psychic         Psi Pokémon  0.9 m (2′11″)
# 3           Absol        Dark    Disaster Pokémon  1.2 m (3′11″)
# 4      Mega Absol        Dark    Disaster Pokémon  1.2 m (3′11″)
#
#                    Peso                                          Abilities  \
# 0  135.5 kg (298.7 lbs)       1. Snow Warning, Soundproof (hidden ability)
# 1  185.0 kg (407.9 lbs)                                    1. Snow Warning
# 2    19.5 kg (43.0 lbs)  1. Synchronize, 2. Inner Focus, Magic Guard (h...
# 3   47.0 kg (103.6 lbs)  1. Pressure, 2. Super Luck, Justified (hidden ...
# 4   49.0 kg (108.0 lbs)                                    1. Magic Bounce
#
#               EV Yield                          Catch Rate  \
# 0  1 Attack, 1 Sp. Atk    60 (7.8% with PokéBall, full HP)
# ...

# %%
misAlturas=miPoke["Altura"]
misAlturas.count()
# Out:
# 1215

# %%
misAlturas.product()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-8fa1d97e8a71> in <cell line: 1>()
# ----> 1 misAlturas.product()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in prod(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11532             **kwargs,
#   11533         ):
# > 11534             return NDFrame.prod(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11535
#   11536         setattr(cls, "prod", prod)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in prod(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11290         **kwargs,
#   11291     ):
# > 11292         return self._min_count_stat_function(
#   11293             "prod",
#   11294             nanops.nanprod,
#
# ...

# %% [markdown]
# # Seleccionar filas especificas
# - Filtrar filas

# %%
misAlturasFiltrado=miPoke[miPoke["Altura"]==0]
misAlturasFiltrado.count()
# Out:
# Pokemon                 0
# Tipo                    0
# Especie                 0
# Altura                  0
# Peso                    0
# Abilities               0
# EV Yield                0
# Catch Rate              0
# Base Friendship         0
# Base Exp                0
# Growth Rate             0
# Egg Groups              0
# Gender                  0
# Egg Cycles              0
# HP Base                 0
# HP Min                  0
# HP Max                  0
# Attack Base             0
# Attack Min              0
# Attack Max              0
# Defense Base            0
# Defense Min             0
# Defense Max             0
# Special Attack Base     0
# Special Attack Min      0
# Special Attack Max      0
# Special Defense Base    0
# Special Defense Min     0
# Special Defense Max     0
# Speed Base              0
# Speed Min               0
# Speed Max               0
# dtype: int64

# %%
miTitanic=pd.read_csv("/content/titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
misSurvivors=miTitanic["Survived"]

# %%
misSurvivorsFiltrado=miTitanic[miTitanic["Survived"]==0]

# %%
totalsobreviviventes=np.sum(misSurvivors)
totalsobreviviventes
# Out:
# 153
