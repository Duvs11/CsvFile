# %%
import pandas as pd

# %%
csvFile='/content/file.csv'

# %%
df=pd.read_csv(csvFile)

# %%
print(df)
# Out:
#                     country_name country_code      1961      1962      1963  \
# 0                          Aruba          ABW  2.179059  1.548572  1.389337
# 1    Africa Eastern and Southern          AFE  2.660180  2.732633  2.753248
# 2                    Afghanistan          AFG  1.925952  2.014879  2.078997
# 3     Africa Western and Central          AFW  2.115789  2.145723  2.190827
# 4                         Angola          AGO  1.558355  1.460738  1.410425
# ..                           ...          ...       ...       ...       ...
# 260          Upper middle income          UMC  0.491945  1.533751  2.446167
# 261                Middle income          MIC  1.314382  1.912035  2.432857
# 262          Lower middle income          LMC  2.405341  2.404450  2.415678
# 263                   Low income          LIC  2.336207  2.374212  2.409516
# 264                  High income          HIC  1.253649  1.266471  1.238717
#
# ...
